# %%
import requests
 
url_kako = "https://api.cultivationdata.net/past"
 
params = {
    "no": "47636",
    "year": 2024,
    "month": 2
}
response = requests.get(url_kako, params=params)
print(response.status_code)
 
raw = response.json()
print(raw)
# Out:
# 200
# {'名古屋（愛知県)': {'2024-2-1': {'現地気圧（平均）': '1011.8', '海面気圧（平均）': '1018.7', '合計降水量': '1.5', '最大1時間降水量': '1.5', '最大10分間降水量': '0.5', '平均気温': '9.1', '最高気温': '15.6', '最低気温': '4.2', '平均湿度': '72', '最小湿度': '37', '平均風速': '4.6', '最大風速': '9.2', '最大風速（風向）': '北西', '最大瞬間風速': '14.1', '最大瞬間風速（風向）': '北北西', '日照時間': '5.9', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '曇時々晴', '天気概況（夜）': '薄曇時々晴'}, '2024-2-2': {'現地気圧（平均）': '1017.0', '海面気圧（平均）': '1024.0', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '4.3', '最高気温': '9.2', '最低気温': '1.5', '平均湿度': '51', '最小湿度': '40', '平均風速': '4.5', '最大風速': '7.8', '最大風速（風向）': '西北西', '最大瞬間風速': '12.0', '最大瞬間風速（風向）': '北西', '日照時間': '6.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々曇', '天気概況（夜）': '晴一時薄曇'}, '2024-2-3': {'現地気圧（平均）': '1019.2', '海面気圧（平均）': '1026.3', '合計降水量': '0.0', '最大1時間降水量': '0.0', '最大10分間降水量': '0.0', '平均気温': '6.2', '最高気温': '11.7', '最低気温': '0.5', '平均湿度': '50', '最小湿度': '30', '平均風速': '2.7', '最大風速': '5.6', '最大風速（風向）': '北', '最大瞬間風速': '8.1', '最大瞬間風速（風向）': '北北西', '日照時間': '7.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々曇', '天気概況（夜）': '雨時々曇'}, '2024-2-4': {'現地気圧（平均）': '1016.5', '海面気圧（平均）': '1023.4', '合計降水量': '0.0', '最大1時間降水量': '0.0', '最大10分間降水量': '0.0', '平均気温': '8.2', '最高気温': '14.2', '最低気温': '5.4', '平均湿度': '60', '最小湿度': '42', '平均風速': '3.4', '最大風速': '6.0', '最大風速（風向）': '北西', '最大瞬間風速': '9.9', '最大瞬間風速（風向）': '北西', '日照時間': '7.6', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴一時雨', '天気概況（夜）': '曇時々晴'}, '2024-2-5': {'現地気圧（平均）': '1009.3', '海面気圧（平均）': '1016.3', '合計降水量': '24.0', '最大1時間降水量': '8.0', '最大10分間降水量': '3.0', '平均気温': '5.0', '最高気温': '6.1', '最低気温': '3.7', '平均湿度': '81', '最小湿度': '51', '平均風速': '3.4', '最大風速': '5.6', '最大風速（風向）': '北東', '最大瞬間風速': '9.6', '最大瞬間風速（風向）': '北西', '日照時間': '0.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '雨一時曇', '天気概況（夜）': '晴時々曇一時雨'}, '2024-2-6': {'現地気圧（平均）': '1010.6', '海面気圧（平均）': '1017.5', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '6.0', '最高気温': '10.9', '最低気温': '2.4', '平均湿度': '69', '最小湿度': '42', '平均風速': '3.9', '最大風速': '8.6', '最大風速（風向）': '西北西', '最大瞬間風速': '13.2', '最大瞬間風速（風向）': '西北西', '日照時間': '7.6', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴一時曇', '天気概況（夜）': '晴'}, '2024-2-7': {'現地気圧（平均）': '1010.5', '海面気圧（平均）': '1017.5', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '5.6', '最高気温': '12.0', '最低気温': '0.9', '平均湿度': '70', '最小湿度': '44', '平均風速': '3.0', '最大風速': '6.8', '最大風速（風向）': '西北西', '最大瞬間風速': '11.1', '最大瞬間風速（風向）': '北西', '日照時間': '9.9', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴', '天気概況（夜）': '快晴'}, '2024-2-8': {'現地気圧（平均）': '1010.6', '海面気圧（平均）': '1017.6', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '5.3', '最高気温': '11.1', '最低気温': '0.4', '平均湿度': '58', '最小湿度': '33', '平均風速': '3.7', '最大風速': '7.5', '最大風速（風向）': '西北西', '最大瞬間風速': '11.8', '最大瞬間風速（風向）': '北西', '日照時間': '9.2', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々薄曇', '天気概況（夜）': '薄曇'}, '2024-2-9': {'現地気圧（平均）': '1011.0', '海面気圧（平均）': '1018.0', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '6.4', '最高気温': '12.0', '最低気温': '2.2', '平均湿度': '52', '最小湿度': '33', '平均風速': '3.0', '最大風速': '5.8', '最大風速（風向）': '北', '最大瞬間風速': '8.3', '最大瞬間風速（風向）': '北北西', '日照時間': '6.1', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々薄曇', '天気概況（夜）': '快晴'}, '2024-2-10': {'現地気圧（平均）': '1011.5', '海面気圧（平均）': '1018.5', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '5.8', '最高気温': '13.1', '最低気温': '0.6', '平均湿度': '67', '最小湿度': '42', '平均風速': '3.2', '最大風速': '8.9', '最大風速（風向）': '西北西', '最大瞬間風速': '12.9', '最大瞬間風速（風向）': '西北西', '日照時間': '9.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々薄曇', '天気概況（夜）': '晴'}, '2024-2-11': {'現地気圧（平均）': '1012.7', '海面気圧（平均）': '1019.7', '合計降水量': '0.0', '最大1時間降水量': '0.0', '最大10分間降水量': '0.0', '平均気温': '6.1', '最高気温': '12.2', '最低気温': '2.3', '平均湿度': '65', '最小湿度': '32', '平均風速': '3.0', '最大風速': '6.1', '最大風速（風向）': '北北西', '最大瞬間風速': '9.6', '最大瞬間風速（風向）': '北北西', '日照時間': '6.9', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々曇', '天気概況（夜）': '曇時々晴'}, '2024-2-12': {'現地気圧（平均）': '1019.6', '海面気圧（平均）': '1026.6', '合計降水量': '0.0', '最大1時間降水量': '0.0', '最大10分間降水量': '0.0' ...

# %%
import pprint
print(raw.keys())
raw2=list(raw.keys())
print(raw2[0]) #これ地名
raw3=raw[raw2[0]] #辞書から抜き出し て値のみ
print(raw3) 
# pprint.pprint(raw3)
date=list(raw3.keys())
print(date)
print(date[0])
print(list(raw.values()))
print(list(raw.items()))
print("")
raw.keys()

number=47636
fetch_date=[]
for k,v in raw3.items(): #アンパッキング
    print(k,v["現地気圧（平均）"])
    print(k,v)
    fetch_date.append(
    {"index_nbr":number,
    "ymd":k,
    "Local_Pressure_(Average)": v["現地気圧（平均）"],
    "Sea_Level_Pressure_(Average)": v["海面気圧（平均）"],
    "Total_Precipitation": v["合計降水量"],
    "Maximum_1-Hour_Precipitation": v["最大1時間降水量"],
    "Maximum_10-Minute_Precipitation": v["最大10分間降水量"],
    "Average_Temperature": v["平均気温"],
    "Maximum_Temperature": v["最高気温"],
    "Minimum_Temperature": v["最低気温"],
    "Average_Humidity": v["平均湿度"],
    "Minimum_Humidity": v["最小湿度"],
    "Average_Wind_Speed": v["平均風速"],
    "Maximum_Wind_Speed": v["最大風速"],
    "Maximum_Wind_Speed_(Direction)": v["最大風速（風向）"],
    "Maximum_Instantaneous_Wind_Speed": v["最大瞬間風速"],
    "Maximum_Instantaneous_Wind_Speed_(Direction)": v["最大瞬間風速（風向）"],
    "Sunshine_Duration": v["日照時間"],
    "Total_Snowfall": v["合計降雪"],
    "Maximum_Snow_Depth": v["最深積雪"],
    "Weather_Summary_(Daytime)": v["天気概況（昼）"],
    "Weather_Summary_(Nighttime)": v["天気概況（夜）"]
    })

print(fetch_date)
# print("-----------------")
# print(tuple(fetch_date[0].values()))
# print("-----------------")
# insert_date=[
# (recode["index_nbr"],
#  recode["ymd"],
#  recode["Local_Pressure_(Average)"],
#  recode["Sea_Level_Pressure_(Average)"],
#  recode["Total_Precipitation"],
#  recode["Maximum_1-Hour_Precipitation"],
#  recode["Maximum_10-Minute_Precipitation"],
#  recode["Average_Temperature"],
#  recode["Maximum_Temperature"],
#  recode["Minimum_Temperature"],
#  recode["Average_Humidity"],
#  recode["Minimum_Humidity"],
#  recode["Average_Wind_Speed"],
#  recode["Maximum_Wind_Speed"],
#  recode["Maximum_Wind_Speed_(Direction)"],
#  recode["Maximum_Instantaneous_Wind_Speed"],
#  recode["Maximum_Instantaneous_Wind_Speed_(Direction)"],
#  recode["Sunshine_Duration"],
#  recode["Total_Snowfall"],
#  recode["Maximum_Snow_Depth"],
#  recode["Weather_Summary_(Daytime)"],
#  recode["Weather_Summary_(Nighttime)"]
#  )
# #リスト内包表記
# for recode in fetch_date
# ]

insert_date=[]
for recode in fetch_date:
    insert_date.append(tuple(recode.values()))

    pass




# for d in date:
#     insert_date.append(tuple(raw3[d].values()))
print(insert_date)
# Out:
# dict_keys(['名古屋（愛知県)'])
# 名古屋（愛知県)
# {'2024-2-1': {'現地気圧（平均）': '1011.8', '海面気圧（平均）': '1018.7', '合計降水量': '1.5', '最大1時間降水量': '1.5', '最大10分間降水量': '0.5', '平均気温': '9.1', '最高気温': '15.6', '最低気温': '4.2', '平均湿度': '72', '最小湿度': '37', '平均風速': '4.6', '最大風速': '9.2', '最大風速（風向）': '北西', '最大瞬間風速': '14.1', '最大瞬間風速（風向）': '北北西', '日照時間': '5.9', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '曇時々晴', '天気概況（夜）': '薄曇時々晴'}, '2024-2-2': {'現地気圧（平均）': '1017.0', '海面気圧（平均）': '1024.0', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '4.3', '最高気温': '9.2', '最低気温': '1.5', '平均湿度': '51', '最小湿度': '40', '平均風速': '4.5', '最大風速': '7.8', '最大風速（風向）': '西北西', '最大瞬間風速': '12.0', '最大瞬間風速（風向）': '北西', '日照時間': '6.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々曇', '天気概況（夜）': '晴一時薄曇'}, '2024-2-3': {'現地気圧（平均）': '1019.2', '海面気圧（平均）': '1026.3', '合計降水量': '0.0', '最大1時間降水量': '0.0', '最大10分間降水量': '0.0', '平均気温': '6.2', '最高気温': '11.7', '最低気温': '0.5', '平均湿度': '50', '最小湿度': '30', '平均風速': '2.7', '最大風速': '5.6', '最大風速（風向）': '北', '最大瞬間風速': '8.1', '最大瞬間風速（風向）': '北北西', '日照時間': '7.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々曇', '天気概況（夜）': '雨時々曇'}, '2024-2-4': {'現地気圧（平均）': '1016.5', '海面気圧（平均）': '1023.4', '合計降水量': '0.0', '最大1時間降水量': '0.0', '最大10分間降水量': '0.0', '平均気温': '8.2', '最高気温': '14.2', '最低気温': '5.4', '平均湿度': '60', '最小湿度': '42', '平均風速': '3.4', '最大風速': '6.0', '最大風速（風向）': '北西', '最大瞬間風速': '9.9', '最大瞬間風速（風向）': '北西', '日照時間': '7.6', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴一時雨', '天気概況（夜）': '曇時々晴'}, '2024-2-5': {'現地気圧（平均）': '1009.3', '海面気圧（平均）': '1016.3', '合計降水量': '24.0', '最大1時間降水量': '8.0', '最大10分間降水量': '3.0', '平均気温': '5.0', '最高気温': '6.1', '最低気温': '3.7', '平均湿度': '81', '最小湿度': '51', '平均風速': '3.4', '最大風速': '5.6', '最大風速（風向）': '北東', '最大瞬間風速': '9.6', '最大瞬間風速（風向）': '北西', '日照時間': '0.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '雨一時曇', '天気概況（夜）': '晴時々曇一時雨'}, '2024-2-6': {'現地気圧（平均）': '1010.6', '海面気圧（平均）': '1017.5', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '6.0', '最高気温': '10.9', '最低気温': '2.4', '平均湿度': '69', '最小湿度': '42', '平均風速': '3.9', '最大風速': '8.6', '最大風速（風向）': '西北西', '最大瞬間風速': '13.2', '最大瞬間風速（風向）': '西北西', '日照時間': '7.6', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴一時曇', '天気概況（夜）': '晴'}, '2024-2-7': {'現地気圧（平均）': '1010.5', '海面気圧（平均）': '1017.5', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '5.6', '最高気温': '12.0', '最低気温': '0.9', '平均湿度': '70', '最小湿度': '44', '平均風速': '3.0', '最大風速': '6.8', '最大風速（風向）': '西北西', '最大瞬間風速': '11.1', '最大瞬間風速（風向）': '北西', '日照時間': '9.9', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴', '天気概況（夜）': '快晴'}, '2024-2-8': {'現地気圧（平均）': '1010.6', '海面気圧（平均）': '1017.6', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '5.3', '最高気温': '11.1', '最低気温': '0.4', '平均湿度': '58', '最小湿度': '33', '平均風速': '3.7', '最大風速': '7.5', '最大風速（風向）': '西北西', '最大瞬間風速': '11.8', '最大瞬間風速（風向）': '北西', '日照時間': '9.2', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々薄曇', '天気概況（夜）': '薄曇'}, '2024-2-9': {'現地気圧（平均）': '1011.0', '海面気圧（平均）': '1018.0', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '6.4', '最高気温': '12.0', '最低気温': '2.2', '平均湿度': '52', '最小湿度': '33', '平均風速': '3.0', '最大風速': '5.8', '最大風速（風向）': '北', '最大瞬間風速': '8.3', '最大瞬間風速（風向）': '北北西', '日照時間': '6.1', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々薄曇', '天気概況（夜）': '快晴'}, '2024-2-10': {'現地気圧（平均）': '1011.5', '海面気圧（平均）': '1018.5', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '5.8', '最高気温': '13.1', '最低気温': '0.6', '平均湿度': '67', '最小湿度': '42', '平均風速': '3.2', '最大風速': '8.9', '最大風速（風向）': '西北西', '最大瞬間風速': '12.9', '最大瞬間風速（風向）': '西北西', '日照時間': '9.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々薄曇', '天気概況（夜）': '晴'}, '2024-2-11': {'現地気圧（平均）': '1012.7', '海面気圧（平均）': '1019.7', '合計降水量': '0.0', '最大1時間降水量': '0.0', '最大10分間降水量': '0.0', '平均気温': '6.1', '最高気温': '12.2', '最低気温': '2.3', '平均湿度': '65', '最小湿度': '32', '平均風速': '3.0', '最大風速': '6.1', '最大風速（風向）': '北北西', '最大瞬間風速': '9.6', '最大瞬間風速（風向）': '北北西', '日照時間': '6.9', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々曇', '天気概況（夜）': '曇時々晴'}, '2024-2-12': {'現地気圧（平均）': '1019.6', '海面気圧（平均）': '1026.6', '合計降水量': '0.0', '最大1時間降水量': '0.0', '最大10分間降水量': '0.0', '平均気温': '6. ...
# ['2024-2-1', '2024-2-2', '2024-2-3', '2024-2-4', '2024-2-5', '2024-2-6', '2024-2-7', '2024-2-8', '2024-2-9', '2024-2-10', '2024-2-11', '2024-2-12', '2024-2-13', '2024-2-14', '2024-2-15', '2024-2-16', '2024-2-17', '2024-2-18', '2024-2-19', '2024-2-20', '2024-2-21', '2024-2-22', '2024-2-23', '2024-2-24', '2024-2-25', '2024-2-26', '2024-2-27', '2024-2-28', '2024-2-29']
# 2024-2-1
# [{'2024-2-1': {'現地気圧（平均）': '1011.8', '海面気圧（平均）': '1018.7', '合計降水量': '1.5', '最大1時間降水量': '1.5', '最大10分間降水量': '0.5', '平均気温': '9.1', '最高気温': '15.6', '最低気温': '4.2', '平均湿度': '72', '最小湿度': '37', '平均風速': '4.6', '最大風速': '9.2', '最大風速（風向）': '北西', '最大瞬間風速': '14.1', '最大瞬間風速（風向）': '北北西', '日照時間': '5.9', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '曇時々晴', '天気概況（夜）': '薄曇時々晴'}, '2024-2-2': {'現地気圧（平均）': '1017.0', '海面気圧（平均）': '1024.0', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '4.3', '最高気温': '9.2', '最低気温': '1.5', '平均湿度': '51', '最小湿度': '40', '平均風速': '4.5', '最大風速': '7.8', '最大風速（風向）': '西北西', '最大瞬間風速': '12.0', '最大瞬間風速（風向）': '北西', '日照時間': '6.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々曇', '天気概況（夜）': '晴一時薄曇'}, '2024-2-3': {'現地気圧（平均）': '1019.2', '海面気圧（平均）': '1026.3', '合計降水量': '0.0', '最大1時間降水量': '0.0', '最大10分間降水量': '0.0', '平均気温': '6.2', '最高気温': '11.7', '最低気温': '0.5', '平均湿度': '50', '最小湿度': '30', '平均風速': '2.7', '最大風速': '5.6', '最大風速（風向）': '北', '最大瞬間風速': '8.1', '最大瞬間風速（風向）': '北北西', '日照時間': '7.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々曇', '天気概況（夜）': '雨時々曇'}, '2024-2-4': {'現地気圧（平均）': '1016.5', '海面気圧（平均）': '1023.4', '合計降水量': '0.0', '最大1時間降水量': '0.0', '最大10分間降水量': '0.0', '平均気温': '8.2', '最高気温': '14.2', '最低気温': '5.4', '平均湿度': '60', '最小湿度': '42', '平均風速': '3.4', '最大風速': '6.0', '最大風速（風向）': '北西', '最大瞬間風速': '9.9', '最大瞬間風速（風向）': '北西', '日照時間': '7.6', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴一時雨', '天気概況（夜）': '曇時々晴'}, '2024-2-5': {'現地気圧（平均）': '1009.3', '海面気圧（平均）': '1016.3', '合計降水量': '24.0', '最大1時間降水量': '8.0', '最大10分間降水量': '3.0', '平均気温': '5.0', '最高気温': '6.1', '最低気温': '3.7', '平均湿度': '81', '最小湿度': '51', '平均風速': '3.4', '最大風速': '5.6', '最大風速（風向）': '北東', '最大瞬間風速': '9.6', '最大瞬間風速（風向）': '北西', '日照時間': '0.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '雨一時曇', '天気概況（夜）': '晴時々曇一時雨'}, '2024-2-6': {'現地気圧（平均）': '1010.6', '海面気圧（平均）': '1017.5', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '6.0', '最高気温': '10.9', '最低気温': '2.4', '平均湿度': '69', '最小湿度': '42', '平均風速': '3.9', '最大風速': '8.6', '最大風速（風向）': '西北西', '最大瞬間風速': '13.2', '最大瞬間風速（風向）': '西北西', '日照時間': '7.6', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴一時曇', '天気概況（夜）': '晴'}, '2024-2-7': {'現地気圧（平均）': '1010.5', '海面気圧（平均）': '1017.5', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '5.6', '最高気温': '12.0', '最低気温': '0.9', '平均湿度': '70', '最小湿度': '44', '平均風速': '3.0', '最大風速': '6.8', '最大風速（風向）': '西北西', '最大瞬間風速': '11.1', '最大瞬間風速（風向）': '北西', '日照時間': '9.9', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴', '天気概況（夜）': '快晴'}, '2024-2-8': {'現地気圧（平均）': '1010.6', '海面気圧（平均）': '1017.6', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '5.3', '最高気温': '11.1', '最低気温': '0.4', '平均湿度': '58', '最小湿度': '33', '平均風速': '3.7', '最大風速': '7.5', '最大風速（風向）': '西北西', '最大瞬間風速': '11.8', '最大瞬間風速（風向）': '北西', '日照時間': '9.2', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々薄曇', '天気概況（夜）': '薄曇'}, '2024-2-9': {'現地気圧（平均）': '1011.0', '海面気圧（平均）': '1018.0', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '6.4', '最高気温': '12.0', '最低気温': '2.2', '平均湿度': '52', '最小湿度': '33', '平均風速': '3.0', '最大風速': '5.8', '最大風速（風向）': '北', '最大瞬間風速': '8.3', '最大瞬間風速（風向）': '北北西', '日照時間': '6.1', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々薄曇', '天気概況（夜）': '快晴'}, '2024-2-10': {'現地気圧（平均）': '1011.5', '海面気圧（平均）': '1018.5', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '5.8', '最高気温': '13.1', '最低気温': '0.6', '平均湿度': '67', '最小湿度': '42', '平均風速': '3.2', '最大風速': '8.9', '最大風速（風向）': '西北西', '最大瞬間風速': '12.9', '最大瞬間風速（風向）': '西北西', '日照時間': '9.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々薄曇', '天気概況（夜）': '晴'}, '2024-2-11': {'現地気圧（平均）': '1012.7', '海面気圧（平均）': '1019.7', '合計降水量': '0.0', '最大1時間降水量': '0.0', '最大10分間降水量': '0.0', '平均気温': '6.1', '最高気温': '12.2', '最低気温': '2.3', '平均湿度': '65', '最小湿度': '32', '平均風速': '3.0', '最大風速': '6.1', '最大風速（風向）': '北北西', '最大瞬間風速': '9.6', '最大瞬間風速（風向）': '北北西', '日照時間': '6.9', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々曇', '天気概況（夜）': '曇時々晴'}, '2024-2-12': {'現地気圧（平均）': '1019.6', '海面気圧（平均）': '1026.6', '合計降水量': '0.0', '最大1時間降水量': '0.0', '最大10分間降水量': '0.0', '平均気温': '6 ...
# [('名古屋（愛知県)', {'2024-2-1': {'現地気圧（平均）': '1011.8', '海面気圧（平均）': '1018.7', '合計降水量': '1.5', '最大1時間降水量': '1.5', '最大10分間降水量': '0.5', '平均気温': '9.1', '最高気温': '15.6', '最低気温': '4.2', '平均湿度': '72', '最小湿度': '37', '平均風速': '4.6', '最大風速': '9.2', '最大風速（風向）': '北西', '最大瞬間風速': '14.1', '最大瞬間風速（風向）': '北北西', '日照時間': '5.9', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '曇時々晴', '天気概況（夜）': '薄曇時々晴'}, '2024-2-2': {'現地気圧（平均）': '1017.0', '海面気圧（平均）': '1024.0', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '4.3', '最高気温': '9.2', '最低気温': '1.5', '平均湿度': '51', '最小湿度': '40', '平均風速': '4.5', '最大風速': '7.8', '最大風速（風向）': '西北西', '最大瞬間風速': '12.0', '最大瞬間風速（風向）': '北西', '日照時間': '6.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々曇', '天気概況（夜）': '晴一時薄曇'}, '2024-2-3': {'現地気圧（平均）': '1019.2', '海面気圧（平均）': '1026.3', '合計降水量': '0.0', '最大1時間降水量': '0.0', '最大10分間降水量': '0.0', '平均気温': '6.2', '最高気温': '11.7', '最低気温': '0.5', '平均湿度': '50', '最小湿度': '30', '平均風速': '2.7', '最大風速': '5.6', '最大風速（風向）': '北', '最大瞬間風速': '8.1', '最大瞬間風速（風向）': '北北西', '日照時間': '7.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々曇', '天気概況（夜）': '雨時々曇'}, '2024-2-4': {'現地気圧（平均）': '1016.5', '海面気圧（平均）': '1023.4', '合計降水量': '0.0', '最大1時間降水量': '0.0', '最大10分間降水量': '0.0', '平均気温': '8.2', '最高気温': '14.2', '最低気温': '5.4', '平均湿度': '60', '最小湿度': '42', '平均風速': '3.4', '最大風速': '6.0', '最大風速（風向）': '北西', '最大瞬間風速': '9.9', '最大瞬間風速（風向）': '北西', '日照時間': '7.6', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴一時雨', '天気概況（夜）': '曇時々晴'}, '2024-2-5': {'現地気圧（平均）': '1009.3', '海面気圧（平均）': '1016.3', '合計降水量': '24.0', '最大1時間降水量': '8.0', '最大10分間降水量': '3.0', '平均気温': '5.0', '最高気温': '6.1', '最低気温': '3.7', '平均湿度': '81', '最小湿度': '51', '平均風速': '3.4', '最大風速': '5.6', '最大風速（風向）': '北東', '最大瞬間風速': '9.6', '最大瞬間風速（風向）': '北西', '日照時間': '0.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '雨一時曇', '天気概況（夜）': '晴時々曇一時雨'}, '2024-2-6': {'現地気圧（平均）': '1010.6', '海面気圧（平均）': '1017.5', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '6.0', '最高気温': '10.9', '最低気温': '2.4', '平均湿度': '69', '最小湿度': '42', '平均風速': '3.9', '最大風速': '8.6', '最大風速（風向）': '西北西', '最大瞬間風速': '13.2', '最大瞬間風速（風向）': '西北西', '日照時間': '7.6', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴一時曇', '天気概況（夜）': '晴'}, '2024-2-7': {'現地気圧（平均）': '1010.5', '海面気圧（平均）': '1017.5', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '5.6', '最高気温': '12.0', '最低気温': '0.9', '平均湿度': '70', '最小湿度': '44', '平均風速': '3.0', '最大風速': '6.8', '最大風速（風向）': '西北西', '最大瞬間風速': '11.1', '最大瞬間風速（風向）': '北西', '日照時間': '9.9', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴', '天気概況（夜）': '快晴'}, '2024-2-8': {'現地気圧（平均）': '1010.6', '海面気圧（平均）': '1017.6', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '5.3', '最高気温': '11.1', '最低気温': '0.4', '平均湿度': '58', '最小湿度': '33', '平均風速': '3.7', '最大風速': '7.5', '最大風速（風向）': '西北西', '最大瞬間風速': '11.8', '最大瞬間風速（風向）': '北西', '日照時間': '9.2', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々薄曇', '天気概況（夜）': '薄曇'}, '2024-2-9': {'現地気圧（平均）': '1011.0', '海面気圧（平均）': '1018.0', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '6.4', '最高気温': '12.0', '最低気温': '2.2', '平均湿度': '52', '最小湿度': '33', '平均風速': '3.0', '最大風速': '5.8', '最大風速（風向）': '北', '最大瞬間風速': '8.3', '最大瞬間風速（風向）': '北北西', '日照時間': '6.1', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々薄曇', '天気概況（夜）': '快晴'}, '2024-2-10': {'現地気圧（平均）': '1011.5', '海面気圧（平均）': '1018.5', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '5.8', '最高気温': '13.1', '最低気温': '0.6', '平均湿度': '67', '最小湿度': '42', '平均風速': '3.2', '最大風速': '8.9', '最大風速（風向）': '西北西', '最大瞬間風速': '12.9', '最大瞬間風速（風向）': '西北西', '日照時間': '9.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々薄曇', '天気概況（夜）': '晴'}, '2024-2-11': {'現地気圧（平均）': '1012.7', '海面気圧（平均）': '1019.7', '合計降水量': '0.0', '最大1時間降水量': '0.0', '最大10分間降水量': '0.0', '平均気温': '6.1', '最高気温': '12.2', '最低気温': '2.3', '平均湿度': '65', '最小湿度': '32', '平均風速': '3.0', '最大風速': '6.1', '最大風速（風向）': '北北西', '最大瞬間風速': '9.6', '最大瞬間風速（風向）': '北北西', '日照時間': '6.9', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々曇', '天気概況（夜）': '曇時々晴'}, '2024-2-12': {'現地気圧（平均）': '1019.6', '海面気圧（平均）': '1026.6', '合計降水量': '0.0', '最大1時間降水量': '0.0', '最大10分間降水量': '0.0 ...
#
# 2024-2-1 1011.8
# 2024-2-1 {'現地気圧（平均）': '1011.8', '海面気圧（平均）': '1018.7', '合計降水量': '1.5', '最大1時間降水量': '1.5', '最大10分間降水量': '0.5', '平均気温': '9.1', '最高気温': '15.6', '最低気温': '4.2', '平均湿度': '72', '最小湿度': '37', '平均風速': '4.6', '最大風速': '9.2', '最大風速（風向）': '北西', '最大瞬間風速': '14.1', '最大瞬間風速（風向）': '北北西', '日照時間': '5.9', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '曇時々晴', '天気概況（夜）': '薄曇時々晴'}
# 2024-2-2 1017.0
# 2024-2-2 {'現地気圧（平均）': '1017.0', '海面気圧（平均）': '1024.0', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '4.3', '最高気温': '9.2', '最低気温': '1.5', '平均湿度': '51', '最小湿度': '40', '平均風速': '4.5', '最大風速': '7.8', '最大風速（風向）': '西北西', '最大瞬間風速': '12.0', '最大瞬間風速（風向）': '北西', '日照時間': '6.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々曇', '天気概況（夜）': '晴一時薄曇'}
# 2024-2-3 1019.2
# 2024-2-3 {'現地気圧（平均）': '1019.2', '海面気圧（平均）': '1026.3', '合計降水量': '0.0', '最大1時間降水量': '0.0', '最大10分間降水量': '0.0', '平均気温': '6.2', '最高気温': '11.7', '最低気温': '0.5', '平均湿度': '50', '最小湿度': '30', '平均風速': '2.7', '最大風速': '5.6', '最大風速（風向）': '北', '最大瞬間風速': '8.1', '最大瞬間風速（風向）': '北北西', '日照時間': '7.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々曇', '天気概況（夜）': '雨時々曇'}
# 2024-2-4 1016.5
# 2024-2-4 {'現地気圧（平均）': '1016.5', '海面気圧（平均）': '1023.4', '合計降水量': '0.0', '最大1時間降水量': '0.0', '最大10分間降水量': '0.0', '平均気温': '8.2', '最高気温': '14.2', '最低気温': '5.4', '平均湿度': '60', '最小湿度': '42', '平均風速': '3.4', '最大風速': '6.0', '最大風速（風向）': '北西', '最大瞬間風速': '9.9', '最大瞬間風速（風向）': '北西', '日照時間': '7.6', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴一時雨', '天気概況（夜）': '曇時々晴'}
# 2024-2-5 1009.3
# 2024-2-5 {'現地気圧（平均）': '1009.3', '海面気圧（平均）': '1016.3', '合計降水量': '24.0', '最大1時間降水量': '8.0', '最大10分間降水量': '3.0', '平均気温': '5.0', '最高気温': '6.1', '最低気温': '3.7', '平均湿度': '81', '最小湿度': '51', '平均風速': '3.4', '最大風速': '5.6', '最大風速（風向）': '北東', '最大瞬間風速': '9.6', '最大瞬間風速（風向）': '北西', '日照時間': '0.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '雨一時曇', '天気概況（夜）': '晴時々曇一時雨'}
# 2024-2-6 1010.6
# 2024-2-6 {'現地気圧（平均）': '1010.6', '海面気圧（平均）': '1017.5', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '6.0', '最高気温': '10.9', '最低気温': '2.4', '平均湿度': '69', '最小湿度': '42', '平均風速': '3.9', '最大風速': '8.6', '最大風速（風向）': '西北西', '最大瞬間風速': '13.2', '最大瞬間風速（風向）': '西北西', '日照時間': '7.6', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴一時曇', '天気概況（夜）': '晴'}
# 2024-2-7 1010.5
# 2024-2-7 {'現地気圧（平均）': '1010.5', '海面気圧（平均）': '1017.5', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '5.6', '最高気温': '12.0', '最低気温': '0.9', '平均湿度': '70', '最小湿度': '44', '平均風速': '3.0', '最大風速': '6.8', '最大風速（風向）': '西北西', '最大瞬間風速': '11.1', '最大瞬間風速（風向）': '北西', '日照時間': '9.9', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴', '天気概況（夜）': '快晴'}
# 2024-2-8 1010.6
# 2024-2-8 {'現地気圧（平均）': '1010.6', '海面気圧（平均）': '1017.6', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '5.3', '最高気温': '11.1', '最低気温': '0.4', '平均湿度': '58', '最小湿度': '33', '平均風速': '3.7', '最大風速': '7.5', '最大風速（風向）': '西北西', '最大瞬間風速': '11.8', '最大瞬間風速（風向）': '北西', '日照時間': '9.2', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々薄曇', '天気概況（夜）': '薄曇'}
# 2024-2-9 1011.0
# 2024-2-9 {'現地気圧（平均）': '1011.0', '海面気圧（平均）': '1018.0', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '6.4', '最高気温': '12.0', '最低気温': '2.2', '平均湿度': '52', '最小湿度': '33', '平均風速': '3.0', '最大風速': '5.8', '最大風速（風向）': '北', '最大瞬間風速': '8.3', '最大瞬間風速（風向）': '北北西', '日照時間': '6.1', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々薄曇', '天気概況（夜）': '快晴'}
# 2024-2-10 1011.5
# 2024-2-10 {'現地気圧（平均）': '1011.5', '海面気圧（平均）': '1018.5', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '5.8', '最高気温': '13.1', '最低気温': '0.6', '平均湿度': '67', '最小湿度': '42', '平均風速': '3.2', '最大風速': '8.9', '最大風速（風向）': '西北西', '最大瞬間風速': '12.9', '最大瞬間風速（風向）': '西北西', '日照時間': '9.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々薄曇', '天気概況（夜）': '晴'}
# 2024-2-11 1012.7
# 2024-2-11 {'現地気圧（平均）': '1012.7', '海面気圧（平均）': '1019.7', '合計降水量': '0.0', '最大1時間降水量': '0.0', '最大10分間降水量': '0.0', '平均気温': '6.1', '最高気温': '12.2', '最低気温': '2.3', '平均湿度': '65', '最小湿度': '32', '平均風速': '3.0', '最大風速': '6.1', '最大風速（風向）': '北北西', '最大瞬間風速': '9.6', '最大瞬間風速（風向）': '北北西', '日照時間': '6.9', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々曇', '天気概況（夜）': '曇時々晴'}
# 2024-2-12 1019.6
# 2024-2-12 {'現地気圧（平均）': '1019.6', '海面気圧（平均）': '1026.6', '合計降水量': '0.0', '最大1時間降水量': '0.0', '最大10分間降水量': '0.0', '平均気温': '6.7', '最高気温': '12.5', '最低気温': '2.2', '平均湿度': '67', '最小湿度': '34', '平均風速': '3.2', '最大風速': '6.6', '最大風速（風向）': '西北西', '最大瞬間風速': '10.3', '最大瞬間風速（風向）': '西北西', '日照時間': '9.5', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴', '天気概況（夜）': '快晴'}
# 2024-2-13 1024.2
# 2024-2-13 {'現地気圧（平均）': '1024.2', '海面気圧（平均）': '1031.3', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '7.5', '最高気温': '14.9', '最低気温': '0.7', '平均湿度': '62', '最小湿度': '37', '平均風速': '1.5', '最大風速': '3.4', '最大風速（風向）': '南南西', '最大瞬間風速': '5.0', '最大瞬間風速（風向）': '南西', '日照時間': '10.3', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '快晴', '天気概況（夜）': '快晴'}
# 2024-2-14 1020.1
# 2024-2-14 {'現地気圧（平均）': '1020.1', '海面気圧（平均）': '1027.0', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '10.9', '最高気温': '19.2', '最低気温': '3.7', '平均湿度': '62', '最小湿度': '35', '平均風速': '1.8', '最大風速': '3.7', '最大風速（風向）': '南西', '最大瞬間風速': '6.3', '最大瞬間風速（風向）': '北', '日照時間': '7.8', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴後薄曇', '天気概況（夜）': '晴後時々曇'}
# 2024-2-15 1010.7
# 2024-2-15 {'現地気圧（平均）': '1010.7', '海面気圧（平均）': '1017.5', '合計降水量': '4.0', '最大1時間降水量': '1.0', '最大10分間降水量': '1.0', '平均気温': '10.8', '最高気温': '14.3', '最低気温': '7.5', '平均湿度': '82', '最小湿度': '61', '平均風速': '1.3', '最大風速': '4.7', '最大風速（風向）': '北北西', '最大瞬間風速': '8.5', '最大瞬間風速（風向）': '北北西', '日照時間': '0.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '曇後時々雨', '天気概況（夜）': '曇時々雨'}
# 2024-2-16 1010.5
# 2024-2-16 {'現地気圧（平均）': '1010.5', '海面気圧（平均）': '1017.4', '合計降水量': '--', '最大1時間降水量': '0.0', '最大10分間降水量': '--', '平均気温': '9.2', '最高気温': '13.4', '最低気温': '6.3', '平均湿度': '52', '最小湿度': '33', '平均風速': '5.6', '最大風速': '9.2', '最大風速（風向）': '北西', '最大瞬間風速': '15.4', '最大瞬間風速（風向）': '北西', '日照時間': '8.9', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴時々曇', '天気概況（夜）': '曇時々晴'}
# 2024-2-17 1016.3
# 2024-2-17 {'現地気圧（平均）': '1016.3', '海面気圧（平均）': '1023.2', '合計降水量': '0.5', '最大1時間降水量': '0.5', '最大10分間降水量': '0.5', '平均気温': '10.1', '最高気温': '15.6', '最低気温': '6.1', '平均湿度': '62', '最小湿度': '42', '平均風速': '2.0', '最大風速': '4.2', '最大風速（風向）': '北北西', '最大瞬間風速': '6.1', '最大瞬間風速（風向）': '北北西', '日照時間': '1.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '曇一時雨', '天気概況（夜）': '曇時々雨'}
# 2024-2-18 1020.3
# 2024-2-18 {'現地気圧（平均）': '1020.3', '海面気圧（平均）': '1027.2', '合計降水量': '0.5', '最大1時間降水量': '0.5', '最大10分間降水量': '0.5', '平均気温': '12.3', '最高気温': '15.7', '最低気温': '10.2', '平均湿度': '85', '最小湿度': '67', '平均風速': '1.6', '最大風速': '3.5', '最大風速（風向）': '南東', '最大瞬間風速': '7.1', '最大瞬間風速（風向）': '東南東', '日照時間': '0.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '曇時々雨', '天気概況（夜）': '雨時々曇'}
# 2024-2-19 1013.9
# 2024-2-19 {'現地気圧（平均）': '1013.9', '海面気圧（平均）': '1020.7', '合計降水量': '47.0', '最大1時間降水量': '6.5', '最大10分間降水量': '1.5', '平均気温': '14.9', '最高気温': '16.3', '最低気温': '12.5', '平均湿度': '97', '最小湿度': '90', '平均風速': '4.2', '最大風速': '7.2', '最大風速（風向）': '南南東', '最大瞬間風速': '12.7', '最大瞬間風速（風向）': '南南東', '日照時間': '0.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '大雨一時曇', '天気概況（夜）': '雨時々曇一時霧'}
# 2024-2-20 1011.5
# 2024-2-20 {'現地気圧（平均）': '1011.5', '海面気圧（平均）': '1018.2', '合計降水量': '2.0', '最大1時間降水量': '1.5', '最大10分間降水量': '0.5', '平均気温': '16.3', '最高気温': '21.6', '最低気温': '12.4', '平均湿度': '82', '最小湿度': '58', '平均風速': '2.8', '最大風速': '6.4', '最大風速（風向）': '西北西', '最大瞬間風速': '9.7', '最大瞬間風速（風向）': '北西', '日照時間': '7.6', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '薄曇一時霧', '天気概況（夜）': '曇時々晴'}
# 2024-2-21 1010.1
# 2024-2-21 {'現地気圧（平均）': '1010.1', '海面気圧（平均）': '1016.9', '合計降水量': '15.0', '最大1時間降水量': '4.5', '最大10分間降水量': '2.5', '平均気温': '12.1', '最高気温': '13.1', '最低気温': '10.9', '平均湿度': '91', '最小湿度': '77', '平均風速': '2.0', '最大風速': '4.9', '最大風速（風向）': '北西', '最大瞬間風速': '8.5', '最大瞬間風速（風向）': '北西', '日照時間': '0.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '雨一時曇', '天気概況（夜）': '雨時々曇'}
# 2024-2-22 1010.6
# 2024-2-22 {'現地気圧（平均）': '1010.6', '海面気圧（平均）': '1017.5', '合計降水量': '7.5', '最大1時間降水量': '2.5', '最大10分間降水量': '1.0', '平均気温': '9.1', '最高気温': '12.0', '最低気温': '5.5', '平均湿度': '79', '最小湿度': '65', '平均風速': '3.6', '最大風速': '5.8', '最大風速（風向）': '北西', '最大瞬間風速': '9.3', '最大瞬間風速（風向）': '北西', '日照時間': '0.6', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '曇時々雨', '天気概況（夜）': '雨時々曇'}
# 2024-2-23 1014.4
# 2024-2-23 {'現地気圧（平均）': '1014.4', '海面気圧（平均）': '1021.4', '合計降水量': '12.5', '最大1時間降水量': '3.0', '最大10分間降水量': '1.0', '平均気温': '5.8', '最高気温': '8.6', '最低気温': '4.3', '平均湿度': '79', '最小湿度': '53', '平均風速': '3.6', '最大風速': '7.3', '最大風速（風向）': '北北西', '最大瞬間風速': '12.3', '最大瞬間風速（風向）': '北北西', '日照時間': '0.3', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '雨時々曇', '天気概況（夜）': '晴一時薄曇'}
# 2024-2-24 1017.9
# 2024-2-24 {'現地気圧（平均）': '1017.9', '海面気圧（平均）': '1024.9', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '6.8', '最高気温': '12.6', '最低気温': '1.8', '平均湿度': '55', '最小湿度': '33', '平均風速': '2.3', '最大風速': '4.6', '最大風速（風向）': '北北西', '最大瞬間風速': '7.0', '最大瞬間風速（風向）': '西南西', '日照時間': '9.7', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴後時々薄曇', '天気概況（夜）': '曇時々雨一時晴'}
# 2024-2-25 1011.4
# 2024-2-25 {'現地気圧（平均）': '1011.4', '海面気圧（平均）': '1018.4', '合計降水量': '6.0', '最大1時間降水量': '1.0', '最大10分間降水量': '0.5', '平均気温': '6.4', '最高気温': '7.4', '最低気温': '5.1', '平均湿度': '91', '最小湿度': '65', '平均風速': '2.7', '最大風速': '5.2', '最大風速（風向）': '北', '最大瞬間風速': '7.4', '最大瞬間風速（風向）': '北', '日照時間': '0.0', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '雨', '天気概況（夜）': '晴時々曇一時雨'}
# 2024-2-26 1009.6
# 2024-2-26 {'現地気圧（平均）': '1009.6', '海面気圧（平均）': '1016.5', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '7.9', '最高気温': '13.5', '最低気温': '4.6', '平均湿度': '56', '最小湿度': '33', '平均風速': '6.2', '最大風速': '10.0', '最大風速（風向）': '北北西', '最大瞬間風速': '17.4', '最大瞬間風速（風向）': '北北西', '日照時間': '10.4', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴', '天気概況（夜）': '晴'}
# 2024-2-27 1014.3
# 2024-2-27 {'現地気圧（平均）': '1014.3', '海面気圧（平均）': '1021.3', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '6.2', '最高気温': '11.9', '最低気温': '3.2', '平均湿度': '47', '最小湿度': '32', '平均風速': '6.3', '最大風速': '10.4', '最大風速（風向）': '北西', '最大瞬間風速': '16.9', '最大瞬間風速（風向）': '北西', '日照時間': '8.0 )', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '晴', '天気概況（夜）': '晴一時薄曇'}
# 2024-2-28 1018.6
# 2024-2-28 {'現地気圧（平均）': '1018.6', '海面気圧（平均）': '1025.6', '合計降水量': '--', '最大1時間降水量': '--', '最大10分間降水量': '--', '平均気温': '7.6', '最高気温': '14.4', '最低気温': '2.3', '平均湿度': '47', '最小湿度': '29', '平均風速': '4.5', '最大風速': '7.7', '最大風速（風向）': '西北西', '最大瞬間風速': '11.0', '最大瞬間風速（風向）': '西北西', '日照時間': '10.9', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '快晴', '天気概況（夜）': '晴時々曇'}
# 2024-2-29 1014.4
# 2024-2-29 {'現地気圧（平均）': '1014.4', '海面気圧（平均）': '1021.4', '合計降水量': '18.0', '最大1時間降水量': '5.5', '最大10分間降水量': '1.5', '平均気温': '6.6', '最高気温': '10.8', '最低気温': '2.9', '平均湿度': '70', '最小湿度': '39', '平均風速': '2.2', '最大風速': '4.3', '最大風速（風向）': '北北西', '最大瞬間風速': '7.0', '最大瞬間風速（風向）': '北北西', '日照時間': '0.1', '合計降雪': '--', '最深積雪': '--', '天気概況（昼）': '曇後時々雨', '天気概況（夜）': '雨後一時曇'}
# [{'index_nbr': 47636, 'ymd': '2024-2-1', 'Local_Pressure_(Average)': '1011.8', 'Sea_Level_Pressure_(Average)': '1018.7', 'Total_Precipitation': '1.5', 'Maximum_1-Hour_Precipitation': '1.5', 'Maximum_10-Minute_Precipitation': '0.5', 'Average_Temperature': '9.1', 'Maximum_Temperature': '15.6', 'Minimum_Temperature': '4.2', 'Average_Humidity': '72', 'Minimum_Humidity': '37', 'Average_Wind_Speed': '4.6', 'Maximum_Wind_Speed': '9.2', 'Maximum_Wind_Speed_(Direction)': '北西', 'Maximum_Instantaneous_Wind_Speed': '14.1', 'Maximum_Instantaneous_Wind_Speed_(Direction)': '北北西', 'Sunshine_Duration': '5.9', 'Total_Snowfall': '--', 'Maximum_Snow_Depth': '--', 'Weather_Summary_(Daytime)': '曇時々晴', 'Weather_Summary_(Nighttime)': '薄曇時々晴'}, {'index_nbr': 47636, 'ymd': '2024-2-2', 'Local_Pressure_(Average)': '1017.0', 'Sea_Level_Pressure_(Average)': '1024.0', 'Total_Precipitation': '--', 'Maximum_1-Hour_Precipitation': '--', 'Maximum_10-Minute_Precipitation': '--', 'Average_Temperature': '4.3', 'Maximum_Temperature': '9.2', 'Minimum_Temperature': '1.5', 'Average_Humidity': '51', 'Minimum_Humidity': '40', 'Average_Wind_Speed': '4.5', 'Maximum_Wind_Speed': '7.8', 'Maximum_Wind_Speed_(Direction)': '西北西', 'Maximum_Instantaneous_Wind_Speed': '12.0', 'Maximum_Instantaneous_Wind_Speed_(Direction)': '北西', 'Sunshine_Duration': '6.0', 'Total_Snowfall': '--', 'Maximum_Snow_Depth': '--', 'Weather_Summary_(Daytime)': '晴時々曇', 'Weather_Summary_(Nighttime)': '晴一時薄曇'}, {'index_nbr': 47636, 'ymd': '2024-2-3', 'Local_Pressure_(Average)': '1019.2', 'Sea_Level_Pressure_(Average)': '1026.3', 'Total_Precipitation': '0.0', 'Maximum_1-Hour_Precipitation': '0.0', 'Maximum_10-Minute_Precipitation': '0.0', 'Average_Temperature': '6.2', 'Maximum_Temperature': '11.7', 'Minimum_Temperature': '0.5', 'Average_Humidity': '50', 'Minimum_Humidity': '30', 'Average_Wind_Speed': '2.7', 'Maximum_Wind_Speed': '5.6', 'Maximum_Wind_Speed_(Direction)': '北', 'Maximum_Instantaneous_Wind_Speed': '8.1', 'Maximum_Instantaneous_Wind_Speed_(Direction)': '北北西', 'Sunshine_Duration': '7.0', 'Total_Snowfall': '--', 'Maximum_Snow_Depth': '--', 'Weather_Summary_(Daytime)': '晴時々曇', 'Weather_Summary_(Nighttime)': '雨時々曇'}, {'index_nbr': 47636, 'ymd': '2024-2-4', 'Local_Pressure_(Average)': '1016.5', 'Sea_Level_Pressure_(Average)': '1023.4', 'Total_Precipitation': '0.0', 'Maximum_1-Hour_Precipitation': '0.0', 'Maximum_10-Minute_Precipitation': '0.0', 'Average_Temperature': '8.2', 'Maximum_Temperature': '14.2', 'Minimum_Temperature': '5.4', 'Average_Humidity': '60', 'Minimum_Humidity': '42', 'Average_Wind_Speed': '3.4', 'Maximum_Wind_Speed': '6.0', 'Maximum_Wind_Speed_(Direction)': '北西', 'Maximum_Instantaneous_Wind_Speed': '9.9', 'Maximum_Instantaneous_Wind_Speed_(Direction)': '北西', 'Sunshine_Duration': '7.6', 'Total_Snowfall': '--', 'Maximum_Snow_Depth': '--', 'Weather_Summary_(Daytime)': '晴一時雨', 'Weather_Summary_(Nighttime)': '曇時々晴'}, {'index_nbr': 47636, 'ymd': '2024-2-5', 'Local_Pressure_(Average)': '1009.3', 'Sea_Level_Pressure_(Average)': '1016.3', 'Total_Precipitation': '24.0', 'Maximum_1-Hour_Precipitation': '8.0', 'Maximum_10-Minute_Precipitation': '3.0', 'Average_Temperature': '5.0', 'Maximum_Temperature': '6.1', 'Minimum_Temperature': '3.7', 'Average_Humidity': '81', 'Minimum_Humidity': '51', 'Average_Wind_Speed': '3.4', 'Maximum_Wind_Speed': '5.6', 'Maximum_Wind_Speed_(Direction)': '北東', 'Maximum_Instantaneous_Wind_Speed': '9.6', 'Maximum_Instantaneous_Wind_Speed_(Direction)': '北西', 'Sunshine_Duration': '0.0', 'Total_Snowfall': '--', 'Maximum_Snow_Depth': '--', 'Weather_Summary_(Daytime)': '雨一時曇', 'Weather_Summary_(Nighttime)': '晴時々曇一時雨'}, {'index_nbr': 47636, 'ymd': '2024-2-6', 'Local_Pressure_(Average)': '1010.6', 'Sea_Level_Pressure_(Average)': '1017.5', 'Total_Precipitation': '--', 'Maximum_1-Hour_Precipitation': '--', 'Maximum_10-Minute_Precipitation': '--', 'Average_Temperature': '6.0', 'Maximum_Temperature': '10.9', 'Minimum_Temperature': '2.4', 'Average_Humidity': '69', 'Minimum_Humidity': ...
# -----------------
# (47636, '2024-2-1', '1011.8', '1018.7', '1.5', '1.5', '0.5', '9.1', '15.6', '4.2', '72', '37', '4.6', '9.2', '北西', '14.1', '北北西', '5.9', '--', '--', '曇時々晴', '薄曇時々晴')
# -----------------
# [(47636, '2024-2-1', '1011.8', '1018.7', '1.5', '1.5', '0.5', '9.1', '15.6', '4.2', '72', '37', '4.6', '9.2', '北西', '14.1', '北北西', '5.9', '--', '--', '曇時々晴', '薄曇時々晴'), (47636, '2024-2-2', '1017.0', '1024.0', '--', '--', '--', '4.3', '9.2', '1.5', '51', '40', '4.5', '7.8', '西北西', '12.0', '北西', '6.0', '--', '--', '晴時々曇', '晴一時薄曇'), (47636, '2024-2-3', '1019.2', '1026.3', '0.0', '0.0', '0.0', '6.2', '11.7', '0.5', '50', '30', '2.7', '5.6', '北', '8.1', '北北西', '7.0', '--', '--', '晴時々曇', '雨時々曇'), (47636, '2024-2-4', '1016.5', '1023.4', '0.0', '0.0', '0.0', '8.2', '14.2', '5.4', '60', '42', '3.4', '6.0', '北西', '9.9', '北西', '7.6', '--', '--', '晴一時雨', '曇時々晴'), (47636, '2024-2-5', '1009.3', '1016.3', '24.0', '8.0', '3.0', '5.0', '6.1', '3.7', '81', '51', '3.4', '5.6', '北東', '9.6', '北西', '0.0', '--', '--', '雨一時曇', '晴時々曇一時雨'), (47636, '2024-2-6', '1010.6', '1017.5', '--', '--', '--', '6.0', '10.9', '2.4', '69', '42', '3.9', '8.6', '西北西', '13.2', '西北西', '7.6', '--', '--', '晴一時曇', '晴'), (47636, '2024-2-7', '1010.5', '1017.5', '--', '--', '--', '5.6', '12.0', '0.9', '70', '44', '3.0', '6.8', '西北西', '11.1', '北西', '9.9', '--', '--', '晴', '快晴'), (47636, '2024-2-8', '1010.6', '1017.6', '--', '--', '--', '5.3', '11.1', '0.4', '58', '33', '3.7', '7.5', '西北西', '11.8', '北西', '9.2', '--', '--', '晴時々薄曇', '薄曇'), (47636, '2024-2-9', '1011.0', '1018.0', '--', '--', '--', '6.4', '12.0', '2.2', '52', '33', '3.0', '5.8', '北', '8.3', '北北西', '6.1', '--', '--', '晴時々薄曇', '快晴'), (47636, '2024-2-10', '1011.5', '1018.5', '--', '--', '--', '5.8', '13.1', '0.6', '67', '42', '3.2', '8.9', '西北西', '12.9', '西北西', '9.0', '--', '--', '晴時々薄曇', '晴'), (47636, '2024-2-11', '1012.7', '1019.7', '0.0', '0.0', '0.0', '6.1', '12.2', '2.3', '65', '32', '3.0', '6.1', '北北西', '9.6', '北北西', '6.9', '--', '--', '晴時々曇', '曇時々晴'), (47636, '2024-2-12', '1019.6', '1026.6', '0.0', '0.0', '0.0', '6.7', '12.5', '2.2', '67', '34', '3.2', '6.6', '西北西', '10.3', '西北西', '9.5', '--', '--', '晴', '快晴'), (47636, '2024-2-13', '1024.2', '1031.3', '--', '--', '--', '7.5', '14.9', '0.7', '62', '37', '1.5', '3.4', '南南西', '5.0', '南西', '10.3', '--', '--', '快晴', '快晴'), (47636, '2024-2-14', '1020.1', '1027.0', '--', '--', '--', '10.9', '19.2', '3.7', '62', '35', '1.8', '3.7', '南西', '6.3', '北', '7.8', '--', '--', '晴後薄曇', '晴後時々曇'), (47636, '2024-2-15', '1010.7', '1017.5', '4.0', '1.0', '1.0', '10.8', '14.3', '7.5', '82', '61', '1.3', '4.7', '北北西', '8.5', '北北西', '0.0', '--', '--', '曇後時々雨', '曇時々雨'), (47636, '2024-2-16', '1010.5', '1017.4', '--', '0.0', '--', '9.2', '13.4', '6.3', '52', '33', '5.6', '9.2', '北西', '15.4', '北西', '8.9', '--', '--', '晴時々曇', '曇時々晴'), (47636, '2024-2-17', '1016.3', '1023.2', '0.5', '0.5', '0.5', '10.1', '15.6', '6.1', '62', '42', '2.0', '4.2', '北北西', '6.1', '北北西', '1.0', '--', '--', '曇一時雨', '曇時々雨'), (47636, '2024-2-18', '1020.3', '1027.2', '0.5', '0.5', '0.5', '12.3', '15.7', '10.2', '85', '67', '1.6', '3.5', '南東', '7.1', '東南東', '0.0', '--', '--', '曇時々雨', '雨時々曇'), (47636, '2024-2-19', '1013.9', '1020.7', '47.0', '6.5', '1.5', '14.9', '16.3', '12.5', '97', '90', '4.2', '7.2', '南南東', '12.7', '南南東', '0.0', '--', '--', '大雨一時曇', '雨時々曇一時霧'), (47636, '2024-2-20', '1011.5', '1018.2', '2.0', '1.5', '0.5', '16.3', '21.6', '12.4', '82', '58', '2.8', '6.4', '西北西', '9.7', '北西', '7.6', '--', '--', '薄曇一時霧', '曇時々晴'), (47636, '2024-2-21', '1010.1', '1016.9', '15.0', '4.5', '2.5', '12.1', '13.1', '10.9', '91', '77', '2.0', '4.9', '北西', '8.5', '北西', '0.0', '--', '--', '雨一時曇', '雨時々曇'), (47636, '2024-2-22', '1010.6', '1017.5', '7.5', '2.5', '1.0', '9.1', '12.0', '5.5', '79', '65', '3.6', '5.8', '北西', '9.3', '北西', '0.6', '--', '--', '曇時々雨', '雨時々曇'), (47636, '2024-2-23', '1014.4', '1021.4', '12.5', '3.0', '1.0', '5.8', '8.6', '4.3', '79', '53', '3.6', '7.3', '北北西', '12.3', '北北西', '0.3', '--', '--', '雨時々曇', '晴一時薄曇'), (47636, '2024-2-24', '1017.9', '1024.9', '--', '--', '--', '6.8', '12.6', '1.8', '55', '33', '2.3', '4.6', '北北西', '7.0', '西南西', '9.7', '--', '--', '晴後時々薄曇', '曇時々雨一時晴'), (47636, '2024-2-25', '1011.4', '1 ...

# %%
import pprint
chimei=list(raw.keys())[0]
date=list(raw[chimei].keys())
first_date=raw[chimei][date[0]]
keys=first_date.keys()
print(list(keys))
pprint.pprint(list(keys))
pprint.pprint(list(first_date.items()))
pprint
# print(raw.keys())
# raw2=list(raw.keys())
# print(list(raw.keys())[0]) #これ地名
# print(raw[list(raw.keys())[0]]) #辞書から抜き出し値のみ
# raw3=raw[raw2[0]] #辞書から抜き出し て値のみ
# print(raw3) 
# # pprint.pprint(raw3)
# raw[list(raw.keys())[0]].keys()
# date=list(raw3.keys())
# print(date[0])#日付のみ
# print(list(raw.values()))
# print(list(raw.items()))
# print("")
# Out:
# ['現地気圧（平均）', '海面気圧（平均）', '合計降水量', '最大1時間降水量', '最大10分間降水量', '平均気温', '最高気温', '最低気温', '平均湿度', '最小湿度', '平均風速', '最大風速', '最大風速（風向）', '最大瞬間風速', '最大瞬間風速（風向）', '日照時間', '合計降雪', '最深積雪', '天気概況（昼）', '天気概況（夜）']
# ['現地気圧（平均）',
#  '海面気圧（平均）',
#  '合計降水量',
#  '最大1時間降水量',
#  '最大10分間降水量',
#  '平均気温',
#  '最高気温',
#  '最低気温',
#  '平均湿度',
#  '最小湿度',
#  '平均風速',
#  '最大風速',
#  '最大風速（風向）',
#  '最大瞬間風速',
#  '最大瞬間風速（風向）',
#  '日照時間',
#  '合計降雪',
#  '最深積雪',
#  '天気概況（昼）',
#  '天気概況（夜）']
# [('現地気圧（平均）', '1011.8'),
#  ('海面気圧（平均）', '1018.7'),
#  ('合計降水量', '1.5'),
#  ('最大1時間降水量', '1.5'),
#  ('最大10分間降水量', '0.5'),
#  ('平均気温', '9.1'),
#  ('最高気温', '15.6'),
#  ('最低気温', '4.2'),
#  ('平均湿度', '72'),
#  ('最小湿度', '37'),
#  ('平均風速', '4.6'),
#  ('最大風速', '9.2'),
#  ('最大風速（風向）', '北西'),
#  ('最大瞬間風速', '14.1'),
#  ('最大瞬間風速（風向）', '北北西'),
#  ('日照時間', '5.9'),
#  ('合計降雪', '--'),
#  ('最深積雪', '--'),
#  ('天気概況（昼）', '曇時々晴'),
#  ('天気概況（夜）', '薄曇時々晴')]

# %%
insert_date[]
for d in date:
insert_date.append(tuple(date[d].values()))
print(insert_date)
# Out:
#   Cell In[1], line 1
#     insert_date[]
#                 ^
# SyntaxError: invalid syntax
